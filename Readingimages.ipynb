# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
files = glob.glob ("C:/Users/Haarika Manda/Desktop/3-2/SRFolder/*.PNG")

# %%
X_data = []
for myFile in files:
    image = cv2.imread (myFile)
    image.shape
    image=np.flip(image, axis=-1) 
    plt.imshow(image)
    X_data.append (image)

# %%
plt.imshow(X_data[0])

# %%
np.array(X_data).shape
# Out:
# (1000, 217, 334, 3)

# %%
np.save('SR_100_samp',np.array(X_data))

# %%
loaded_array = np.load('SR_100_samp.npy')

# %%
loaded_array.shape
# Out:
# (1000, 217, 334, 3)
